# %%
# !git clone https://github.com/CS7IS4-Connections/Connections.git
# Out:
# Cloning into 'Connections'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 189 (delta 8), reused 4 (delta 4), pack-reused 179 (from 1)
# Receiving objects: 100% (189/189), 165.27 MiB | 44.57 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
# !ls Connections
# !cd Connections && git log -1
# Out:
# CLAUDE.md  paper	     results	      src
# data	   requirements.txt  run_pipeline.py  text-analytics.ipynb
# commit a5416e9c24c9fccab59297af9e57fc5014316620 (HEAD -> main, origin/main, origin/HEAD)
# Author: stevinjs <stevinjs@tcd.ie>
# Date:   Fri Apr 10 03:16:54 2026 +0100
#
#     latest with new figures and results from step 1 step 2 for 30k.

# %%
# !pip install -r Connections/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 102.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
# ...

# %%
# !python -m spacy download en_core_web_trf
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 33.5 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 98.2 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# ...

# %%
# !gunzip Connections/data/samples/sample_30k.csv.gz

# %%
# !ls Connections/data/samples
# Out:
# sample_30k.csv	sample_5k.csv  sample_data_clean.csv

# %%
# !pwd
# Out:
# /kaggle/working

# %%
# !ls Connections/results
# Out:
# figures				sample_results_step1_structural.csv
# sample_results.csv		sample_results_step2_similarity.csv
# sample_results_step0_input.csv	sample_results_step3_entity.csv

# %%
# !tail Connections/data/samples/sample_30k.csv -n 1
# Out:
# 862431,guardian,sport,sport,Richie Porte left and Mikel Nieve at the finish of the 13th stage of the Tour de France during which Porte lost 8min 49sec,"After two years of dominance at the Tour de France, it is all change at Team Sky. Where in July 2012 and 2013 it was virtually impossible to get near the “Death Star” – as their colossal black bus is nicknamed – at stage starts and finishes due to the crush of media and fans, it has suddenly gone suspiciously quiet. The action is elsewhere, around Astana and AG2R. Not even the presence of Alastair Campbell on Sunday could create a buzz. Chris Froome’s crashes and the virus that cost Richie Porte his chance of a high finish mean that the British team have suddenly found themselves back in the position they were in 2011 and 2010, when their then-leader, Bradley Wiggins, was absent – in 2011 physically due to a crash, in 2010 spiritually due to his inability to race at his level of 2009, and the pressures of leadership. The talk two-and-
# ...

# %%
# !cd Connections && python run_pipeline.py --input data/samples/sample_30k.csv --output results/sample_30k_results.csv

# %%
# !tail /kaggle/input/datasets/jayanandenm/text-step-runs/sample_30k_results_step2_similarity.csv -n 1
# Out:
# 862431,guardian,sport,sport,Richie Porte left and Mikel Nieve at the finish of the 13th stage of the Tour de France during which Porte lost 8min 49sec,"After two years of dominance at the Tour de France, it is all change at Team Sky. Where in July 2012 and 2013 it was virtually impossible to get near the “Death Star” – as their colossal black bus is nicknamed – at stage starts and finishes due to the crush of media and fans, it has suddenly gone suspiciously quiet. The action is elsewhere, around Astana and AG2R. Not even the presence of Alastair Campbell on Sunday could create a buzz. Chris Froome’s crashes and the virus that cost Richie Porte his chance of a high finish mean that the British team have suddenly found themselves back in the position they were in 2011 and 2010, when their then-leader, Bradley Wiggins, was absent – in 2011 physically due to a crash, in 2010 spiritually due to his inability to race at his level of 2009, and the pressures of leadership. The talk two-and-
# ...

# %%
import spacy                                                                                                          
spacy.prefer_gpu()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Found GPU0 Tesla P100-PCIE-16GB which is of cuda capability 6.0.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   queued_call()
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:435: UserWarning:
# Tesla P100-PCIE-16GB with CUDA capability sm_60 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the Tesla P100-PCIE-16GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   queued_call()
# True

# %%
import torch                                                                                                          
print(torch.cuda.is_available())
# Out:
# True

# %%
# !cd Connections && python src/entity_alignment.py --input /kaggle/input/datasets/jayanandenm/text-step-runs/sample_30k_results_step2_similarity.csv --output results/sample_30k_results_step3_entity.csv
# Out:
# Entity alignment chunks: 100%|███████████████| 60/60 [8:45:38<00:00, 525.64s/it]
# Wrote 30,000 rows -> results/sample_30k_results_step3_entity.csv
# Checkpoint removed: results/sample_30k_results_step3_entity.csv.partial

# %%
# !cd Connections && python src/caption_classifier.py --input results/sample_30k_results_step3_entity.csv --output results/sample_30k_results.csv
# Out:
# Classifying captions: 100%|███████████████| 30000/30000 [19:05<00:00, 26.18it/s]
#
# === Caption Type Distribution ===
#   Independent     13,792  (46.0%)
#   Extractive      11,198  (37.3%)
#   Expansive        4,231  (14.1%)
#   Descriptive        779  (2.6%)
#
# By source:
# caption_type  Descriptive  Expansive  Extractive  Independent
# source
# bbc                   123        877        2464         3523
# guardian              656       3354        8734        10269
#
# Wrote 30,000 rows -> results/sample_30k_results.csv

# %%
# !cd Connections && zip -r results.zip results
# Out:
#   adding: results/ (stored 0%)
#   adding: results/.gitkeep (stored 0%)
#   adding: results/sample_results_step2_similarity.csv (deflated 59%)
#   adding: results/sample_results_step0_input.csv (deflated 60%)
#   adding: results/sample_results.csv (deflated 59%)
#   adding: results/sample_30k_results_step3_entity.csv (deflated 60%)
#   adding: results/sample_results_step3_entity.csv (deflated 59%)
#   adding: results/sample_results_step1_structural.csv (deflated 60%)
#   adding: results/figures/ (stored 0%)
#   adding: results/figures/fig03_structural_correlations.png (deflated 4%)
#   adding: results/figures/table3_regression.tex (deflated 60%)
#   adding: results/figures/fig13_similarity_by_source.png (deflated 10%)
#   adding: results/figures/fig15_source_category_heatmap.png (deflated 6%)
#   adding: results/figures/table1_descriptive_stats.csv (deflated 47%)
#   adding: results/figures/fig01_similarity_distributions.png (deflated 5%)
# ...
