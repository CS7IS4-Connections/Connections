# %%
# !git clone https://github.com/CS7IS4-Connections/Connections.git
# Out:
# Cloning into 'Connections'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 136 (delta 8), reused 7 (delta 5), pack-reused 118 (from 2)
# Receiving objects: 100% (136/136), 177.32 MiB | 34.41 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# !ls Connections
# !cd Connections && git log -1
# Out:
# CLAUDE.md  data  paper	requirements.txt  results  run_pipeline.py  src
# commit 6aece6326b2e358b882d5a8a82f11adcad4fa0f1 (HEAD -> main, origin/main, origin/HEAD)
# Author: jayananden m <jayananden@gmail.com>
# Date:   Wed Apr 8 22:55:20 2026 +0100
#
#     Downsample to 30k and Add back the zip data

# %%
# !pip install -r Connections/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.5/780.5 kB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.4/313.4 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 84.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
# ...

# %%
# !python -m spacy download en_core_web_trf
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.9/237.9 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.0/734.0 kB 22.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 72.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# ...

# %%
# !gunzip Connections/data/samples/sample_90k.csv.gz
# Out:
# gzip: Connections/data/samples/sample_90k.csv.gz: No such file or directory

# %%
# !ls Connections/data/samples
# Out:
# sample_30k.csv.gz  sample_5k.csv  sample_data_clean.csv

# %%
# !head Connections/data/samples/sample_90k.csv -n 2
# Out:
# head: cannot open 'Connections/data/samples/sample_90k.csv' for reading: No such file or directory

# %%
# !tail Connections/data/samples/sample_90k.csv -n 1
# Out:
# tail: cannot open 'Connections/data/samples/sample_90k.csv' for reading: No such file or directory

# %%
# !cd Connections && python run_pipeline.py --input data/samples/sample_90k.csv --output results/sample_results.csv
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/Connections/run_pipeline.py", line 134, in <module>
#     main()
#   File "/kaggle/working/Connections/run_pipeline.py", line 75, in main
#     df_in = pd.read_csv(args.input)
#             ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !cd Connections && zip -r results.zip results
# Out:
#   adding: results/ (stored 0%)
#   adding: results/sample_results_step0_input.csv (deflated 60%)
#   adding: results/figures/ (stored 0%)
#   adding: results/figures/caption_length_distribution.png (deflated 17%)
#   adding: results/figures/table_rq1_correlations.tex (deflated 66%)
#   adding: results/figures/table_rq5_similarity_by_source.csv (deflated 28%)
#   adding: results/figures/rq5_similarity_by_source.png (deflated 3%)
#   adding: results/figures/table_dataset_stats.csv (deflated 15%)
#   adding: results/figures/table_rq5_dunn_posthoc.csv (deflated 29%)
#   adding: results/figures/table_rq5_similarity_by_source.tex (deflated 33%)
#   adding: results/figures/rq3_entity_jaccard_vs_sbert.png (deflated 2%)
#   adding: results/figures/table_rq5_dunn_posthoc.tex (deflated 30%)
#   adding: results/figures/rq4_similarity_by_category.png (deflated 3%)
#   adding: results/figures/table_rq3_entity_metrics.csv (deflated 31%)
# ...
